# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnists

mnist = mnists.MNIST()
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)
# Out:
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-images-idx3-ubyte.gz to /tmp/mnists/MNIST/train-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/train-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/train-labels-idx1-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-images-idx3-ubyte.gz to /tmp/mnists/MNIST/t10k-images-idx3-ubyte.gz
# Downloading https://storage.googleapis.com/cvdf-datasets/mnist/t10k-labels-idx1-ubyte.gz to /tmp/mnists/MNIST/t10k-labels-idx1-ubyte.gz
# /tmp/ipykernel_10658/2858327892.py:4: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size))

# %%
def reconstuction_error(rbm, minibatch):
    print(minibatch.shape)
    print(rbm.visible_size)
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(*(minibatch @ rbm.W[:, :-1]).shape)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / minibatch.shape[0]

    return error

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])

    # Negative
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(*(positive_hidden[:, :-1]).shape)
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    for step in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(*(negative_visible @ rbm.W[:, :-1]).shape)
    
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    positive_grad = positive_visible.T @ positive_hidden
    negative_grad = negative_visible.T @ negative_hidden

    rbm.W += rbm.learning_rate * ((positive_grad - negative_grad) / observations_count)

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))

    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])

    # Negative
    negative_hidden[:, :-1] = rbm.PC[:, :-1]
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    for _ in range(k - 1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(*(negative_visible @ rbm.W[:, :-1]).shape)
    
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    rbm.PC[:, :-1] = negative_hidden[:, :-1] > rand(*negative_hidden[:, :-1].shape)

    positive_grad = (positive_visible.T @ positive_hidden) / observations_count
    negative_grad = (negative_visible.T @ negative_hidden) / rbm.pc_count

    rbm.W += rbm.learning_rate * positive_grad - rbm.learning_rate * negative_grad

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]
# Out:
# /tmp/ipykernel_10658/3750985892.py:11: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# /tmp/ipykernel_10658/1605016057.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################(256, 785)
# 784
# 	elapsed: 1.30s, reconstruction error: 32.27
# Epoch 1:	#####################################################(256, 785)
# 784
# 	elapsed: 0.75s, reconstruction error: 26.06
# Epoch 2:	#####################################################(256, 785)
# 784
# 	elapsed: 1.16s, reconstruction error: 22.68
# Epoch 3:	#####################################################(256, 785)
# 784
# 	elapsed: 0.94s, reconstruction error: 20.66
# Epoch 4:	#####################################################(256, 785)
# 784
# 	elapsed: 0.59s, reconstruction error: 19.29
# Epoch 5:	#####################################################(256, 785)
# 784
# 	elapsed: 0.62s, reconstruction error: 18.35
# Epoch 6:	#####################################################(256, 785)
# 784
# 	elapsed: 0.95s, reconstruction error: 17.40
# Epoch 7:	#####################################################(256, 785)
# 784
# 	elapsed: 0.88s, reconstruction error: 16.87
# Epoch 8:	#####################################################(256, 785)
# 784
# 	elapsed: 6.30s, reconstruction error: 16.40
# Epoch 9:	#####################################################(256, 785)
# 784
# 	elapsed: 9.85s, reconstruction error: 15.93
# Epoch 10:	#####################################################(256, 785)
# 784
# 	elapsed: 5.23s, reconstruction error: 15.48
# Epoch 11:	#####################################################(256, 785)
# 784
# 	elapsed: 2.91s, reconstruction error: 15.04
# Epoch 12:	#####################################################(256, 785)
# 784
# 	elapsed: 3.59s, reconstruction error: 14.91
# Epoch 13:	#####################################################(256, 785)
# 784
# 	elapsed: 1.29s, reconstruction error: 14.42
# Epoch 14:	#####################################################(256, 785)
# 784
# 	elapsed: 1.14s, reconstruction error: 14.23
# Epoch 15:	#####################################################(256, 785)
# 784
# 	elapsed: 2.69s, reconstruction error: 14.01
# Epoch 16:	#####################################################(256, 785)
# 784
# 	elapsed: 3.07s, reconstruction error: 14.07
# Epoch 17:	#####################################################(256, 785)
# 784
# 	elapsed: 1.93s, reconstruction error: 13.60
# Epoch 18:	#####################################################(256, 785)
# 784
# 	elapsed: 3.25s, reconstruction error: 13.54
# Epoch 19:	#####################################################(256, 785)
# 784
# 	elapsed: 10.02s, reconstruction error: 13.34
# Epoch 20:	#####################################################(256, 785)
# 784
# 	elapsed: 7.42s, reconstruction error: 13.11
# Epoch 21:	#####################################################(256, 785)
# 784
# 	elapsed: 6.29s, reconstruction error: 13.00
# Epoch 22:	#####################################################(256, 785)
# 784
# 	elapsed: 7.38s, reconstruction error: 12.78
# Epoch 23:	#####################################################(256, 785)
# 784
# 	elapsed: 7.19s, reconstruction error: 12.67
# Epoch 24:	#####################################################(256, 785)
# 784
# 	elapsed: 1.97s, reconstruction error: 12.43
# Epoch 25:	#####################################################(256, 785)
# 784
# 	elapsed: 0.73s, reconstruction error: 12.64
# Epoch 26:	#####################################################(256, 785)
# 784
# 	elapsed: 1.73s, reconstruction error: 12.29
# Epoch 27:	#####################################################(256, 785)
# 784
# 	elapsed: 1.74s, reconstruction error: 12.20
# Epoch 28:	#####################################################(256, 785)
# 784
# 	elapsed: 0.78s, reconstruction error: 12.09
# Epoch 29:	#####################################################(256, 785)
# 784
# 	elapsed: 0.91s, reconstruction error: 12.16
# Epoch 30:	#####################################################(256, 785)
# 784
# 	elapsed: 0.66s, reconstruction error: 12.03
# Epoch 31:	#####################################################(256, 785)
# 784
# 	elapsed: 0.96s, reconstruction error: 11.92
# Epoch 32:	#####################################################(256, 785)
# 784
# 	elapsed: 2.37s, reconstruction error: 11.96
# Epoch 33:	#####################################################(256, 785)
# 784
# 	elapsed: 0.65s, reconstruction error: 11.72
# Epoch 34:	#####################################################(256, 785)
# 784
# 	elapsed: 0.67s, reconstruction error: 11.73
# Epoch 35:	#####################################################(256, 785)
# 784
# 	elapsed: 0.89s, reconstruction error: 11.67
# Epoch 36:	#####################################################(256, 785)
# 784
# 	elapsed: 1.22s, reconstruction error: 11.62
# Epoch 37:	#####################################################(256, 785)
# 784
# 	elapsed: 1.73s, reconstruction error: 11.45
# Epoch 38:	#####################################################(256, 785)
# 784
# 	elapsed: 0.67s, reconstruction error: 11.71
# Epoch 39:	#####################################################(256, 785)
# 784
# 	elapsed: 0.78s, reconstruction error: 11.37
# Epoch 40:	#####################################################(256, 785)
# 784
# 	elapsed: 0.76s, reconstruction error: 11.29
# Epoch 41:	#####################################################(256, 785)
# 784
# 	elapsed: 0.74s, reconstruction error: 11.36
# Epoch 42:	#####################################################(256, 785)
# 784
# 	elapsed: 1.57s, reconstruction error: 11.30
# Epoch 43:	#####################################################(256, 785)
# 784
# 	elapsed: 1.13s, reconstruction error: 11.18
# Epoch 44:	#####################################################(256, 785)
# 784
# 	elapsed: 0.95s, reconstruction error: 11.21
# Epoch 45:	#####################################################(256, 785)
# 784
# 	elapsed: 0.76s, reconstruction error: 11.17
# Epoch 46:	#####################################################(256, 785)
# 784
# 	elapsed: 0.67s, reconstruction error: 11.23
# Epoch 47:	#####################################################(256, 785)
# 784
# 	elapsed: 1.22s, reconstruction error: 10.97
# Epoch 48:	#####################################################(256, 785)
# 784
# 	elapsed: 2.14s, reconstruction error: 10.96
# Epoch 49:	#####################################################(256, 785)
# 784
# 	elapsed: 1.45s, reconstruction error: 11.09
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# /tmp/ipykernel_10658/1605016057.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################(256, 785)
# 784
# 	elapsed: 2.02s, reconstruction error: 84.70
# Epoch 1:	#####################################################(256, 785)
# 784
# 	elapsed: 2.58s, reconstruction error: 54.70
# Epoch 2:	#####################################################(256, 785)
# 784
# 	elapsed: 5.11s, reconstruction error: 30.43
# Epoch 3:	#####################################################(256, 785)
# 784
# 	elapsed: 3.36s, reconstruction error: 23.03
# Epoch 4:	#####################################################(256, 785)
# 784
# 	elapsed: 1.83s, reconstruction error: 19.40
# Epoch 5:	#####################################################(256, 785)
# 784
# 	elapsed: 1.56s, reconstruction error: 16.96
# Epoch 6:	#####################################################(256, 785)
# 784
# 	elapsed: 1.70s, reconstruction error: 15.16
# Epoch 7:	#####################################################(256, 785)
# 784
# 	elapsed: 1.85s, reconstruction error: 13.28
# Epoch 8:	#####################################################(256, 785)
# 784
# 	elapsed: 2.43s, reconstruction error: 12.10
# Epoch 9:	#####################################################(256, 785)
# 784
# 	elapsed: 2.64s, reconstruction error: 10.67
# Epoch 10:	#####################################################(256, 785)
# 784
# 	elapsed: 1.58s, reconstruction error: 9.81
# Epoch 11:	#####################################################(256, 785)
# 784
# 	elapsed: 1.59s, reconstruction error: 9.44
# Epoch 12:	#####################################################(256, 785)
# 784
# 	elapsed: 1.80s, reconstruction error: 8.82
# Epoch 13:	#####################################################(256, 785)
# 784
# 	elapsed: 2.23s, reconstruction error: 8.26
# Epoch 14:	#####################################################(256, 785)
# 784
# 	elapsed: 3.34s, reconstruction error: 8.05
# Epoch 15:	#####################################################(256, 785)
# 784
# 	elapsed: 7.08s, reconstruction error: 7.36
# Epoch 16:	#####################################################(256, 785)
# 784
# 	elapsed: 4.48s, reconstruction error: 7.04
# Epoch 17:	#####################################################(256, 785)
# 784
# 	elapsed: 2.28s, reconstruction error: 6.86
# Epoch 18:	#####################################################(256, 785)
# 784
# 	elapsed: 2.26s, reconstruction error: 6.53
# Epoch 19:	#####################################################(256, 785)
# 784
# 	elapsed: 1.77s, reconstruction error: 6.17
# Epoch 20:	#####################################################(256, 785)
# 784
# 	elapsed: 3.86s, reconstruction error: 6.08
# Epoch 21:	#####################################################(256, 785)
# 784
# 	elapsed: 1.72s, reconstruction error: 5.74
# Epoch 22:	#####################################################(256, 785)
# 784
# 	elapsed: 1.82s, reconstruction error: 5.51
# Epoch 23:	#####################################################(256, 785)
# 784
# 	elapsed: 1.73s, reconstruction error: 5.35
# Epoch 24:	#####################################################(256, 785)
# 784
# 	elapsed: 1.45s, reconstruction error: 5.02
# Epoch 25:	#####################################################(256, 785)
# 784
# 	elapsed: 6.90s, reconstruction error: 4.87
# Epoch 26:	#####################################################(256, 785)
# 784
# 	elapsed: 1.82s, reconstruction error: 4.91
# Epoch 27:	#####################################################(256, 785)
# 784
# 	elapsed: 1.86s, reconstruction error: 4.60
# Epoch 28:	#####################################################(256, 785)
# 784
# 	elapsed: 1.65s, reconstruction error: 4.51
# Epoch 29:	#####################################################(256, 785)
# 784
# 	elapsed: 1.51s, reconstruction error: 4.30
# Epoch 30:	#####################################################(256, 785)
# 784
# 	elapsed: 1.82s, reconstruction error: 4.22
# Epoch 31:	#####################################################(256, 785)
# 784
# 	elapsed: 2.94s, reconstruction error: 4.29
# Epoch 32:	#####################################################(256, 785)
# 784
# 	elapsed: 2.21s, reconstruction error: 4.10
# Epoch 33:	#####################################################(256, 785)
# 784
# 	elapsed: 2.12s, reconstruction error: 4.05
# Epoch 34:	#####################################################(256, 785)
# 784
# 	elapsed: 1.51s, reconstruction error: 3.95
# Epoch 35:	#####################################################(256, 785)
# 784
# 	elapsed: 2.10s, reconstruction error: 3.80
# Epoch 36:	#####################################################(256, 785)
# 784
# 	elapsed: 1.83s, reconstruction error: 3.74
# Epoch 37:	#####################################################(256, 785)
# 784
# 	elapsed: 1.46s, reconstruction error: 3.81
# Epoch 38:	#####################################################(256, 785)
# 784
# 	elapsed: 1.96s, reconstruction error: 3.80
# Epoch 39:	#####################################################(256, 785)
# 784
# 	elapsed: 1.77s, reconstruction error: 3.74
# Epoch 40:	#####################################################(256, 785)
# 784
# 	elapsed: 2.04s, reconstruction error: 3.78
# Epoch 41:	#####################################################(256, 785)
# 784
# 	elapsed: 2.02s, reconstruction error: 3.68
# Epoch 42:	#####################################################(256, 785)
# 784
# 	elapsed: 1.48s, reconstruction error: 3.49
# Epoch 43:	#####################################################(256, 785)
# 784
# 	elapsed: 1.72s, reconstruction error: 3.49
# Epoch 44:	#####################################################(256, 785)
# 784
# 	elapsed: 1.81s, reconstruction error: 3.38
# Epoch 45:	#####################################################(256, 785)
# 784
# 	elapsed: 5.24s, reconstruction error: 3.47
# Epoch 46:	#####################################################(256, 785)
# 784
# 	elapsed: 5.28s, reconstruction error: 3.51
# Epoch 47:	#####################################################(256, 785)
# 784
# 	elapsed: 5.98s, reconstruction error: 3.40
# Epoch 48:	#####################################################(256, 785)
# 784
# 	elapsed: 8.95s, reconstruction error: 3.51
# Epoch 49:	#####################################################(256, 785)
# 784
# 	elapsed: 2.65s, reconstruction error: 3.39
# Training finished!
