# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnists

mnist = mnists.MNIST()
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)
# Out:
# /tmp/ipykernel_4463/2858327892.py:4: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size)) # (128, 128)

# %%
def reconstuction_error(rbm, minibatch):
    print(minibatch.shape)
    print(rbm.visible_size)
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(*(minibatch @ rbm.W[:, :-1]).shape)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / minibatch.shape[0]

    return error

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])

    # Negative
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(*(positive_hidden[:, :-1]).shape)
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    for step in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(*(negative_visible @ rbm.W[:, :-1]).shape)
    
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    positive_grad = positive_visible.T @ positive_hidden
    negative_grad = negative_visible.T @ negative_hidden

    rbm.W += rbm.learning_rate * ((positive_grad - negative_grad) / observations_count)

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))

    # Positive
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])

    # Negative
    # negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(*(positive_hidden[:, :-1]).shape)
    # negative_hidden[:, :-1] = rbm.PC[:, :-1] > rand(*(rbm.PC[:, :-1]).shape)
    negative_hidden = rbm.PC
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*(negative_hidden @ rbm.W[:-1, :].T).shape)

    for step in range(k-1):
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(*negative_visible @ rbm.W[:, :-1].shape)
    
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(*negative_hidden @ rbm.W[:-1, :].T.shape)

    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    positive_grad = positive_visible.T @ positive_hidden
    negative_grad = negative_visible.T @ negative_hidden

    rbm.PC[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])

    rbm.W += rbm.learning_rate * ((positive_grad - negative_grad) / observations_count)

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

# draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# /tmp/ipykernel_4463/1605016057.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################(256, 785)
# 784
# 	elapsed: 0.49s, reconstruction error: 50.37
# Epoch 1:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 31.34
# Epoch 2:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 22.99
# Epoch 3:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 20.78
# Epoch 4:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 17.80
# Epoch 5:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 15.64
# Epoch 6:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 14.04
# Epoch 7:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 12.69
# Epoch 8:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 11.54
# Epoch 9:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 10.69
# Epoch 10:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 10.05
# Epoch 11:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 9.34
# Epoch 12:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 8.67
# Epoch 13:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 8.33
# Epoch 14:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 7.78
# Epoch 15:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 7.44
# Epoch 16:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 7.07
# Epoch 17:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 6.82
# Epoch 18:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 6.57
# Epoch 19:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 6.15
# Epoch 20:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 5.94
# Epoch 21:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 5.62
# Epoch 22:	#####################################################(256, 785)
# 784
# 	elapsed: 0.44s, reconstruction error: 5.45
# Epoch 23:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 5.30
# Epoch 24:	#####################################################(256, 785)
# 784
# 	elapsed: 0.55s, reconstruction error: 5.17
# Epoch 25:	#####################################################(256, 785)
# 784
# 	elapsed: 0.50s, reconstruction error: 4.97
# Epoch 26:	#####################################################(256, 785)
# 784
# 	elapsed: 0.59s, reconstruction error: 4.83
# Epoch 27:	#####################################################(256, 785)
# 784
# 	elapsed: 0.41s, reconstruction error: 4.74
# Epoch 28:	#####################################################(256, 785)
# 784
# 	elapsed: 0.43s, reconstruction error: 4.66
# Epoch 29:	#####################################################(256, 785)
# 784
# 	elapsed: 0.42s, reconstruction error: 4.47
# Epoch 30:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 4.41
# Epoch 31:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 4.34
# Epoch 32:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 4.23
# Epoch 33:	#####################################################(256, 785)
# 784
# 	elapsed: 0.41s, reconstruction error: 4.11
# Epoch 34:	#####################################################(256, 785)
# 784
# 	elapsed: 0.42s, reconstruction error: 4.08
# Epoch 35:	#####################################################(256, 785)
# 784
# 	elapsed: 0.44s, reconstruction error: 4.09
# Epoch 36:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 4.01
# Epoch 37:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 3.92
# Epoch 38:	#####################################################(256, 785)
# 784
# 	elapsed: 0.48s, reconstruction error: 3.93
# Epoch 39:	#####################################################(256, 785)
# 784
# 	elapsed: 0.45s, reconstruction error: 3.83
# Epoch 40:	#####################################################(256, 785)
# 784
# 	elapsed: 0.83s, reconstruction error: 3.81
# Epoch 41:	#####################################################(256, 785)
# 784
# 	elapsed: 0.52s, reconstruction error: 3.79
# Epoch 42:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 3.62
# Epoch 43:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 3.70
# Epoch 44:	#####################################################(256, 785)
# 784
# 	elapsed: 0.43s, reconstruction error: 3.70
# Epoch 45:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 3.66
# Epoch 46:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 3.71
# Epoch 47:	#####################################################(256, 785)
# 784
# 	elapsed: 0.54s, reconstruction error: 3.74
# Epoch 48:	#####################################################(256, 785)
# 784
# 	elapsed: 0.75s, reconstruction error: 3.67
# Epoch 49:	#####################################################(256, 785)
# 784
# 	elapsed: 1.09s, reconstruction error: 3.68
# Training finished!

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]
# Out:
# /tmp/ipykernel_4463/3750985892.py:11: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# /tmp/ipykernel_4463/1605016057.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################(256, 785)
# 784
# 	elapsed: 0.45s, reconstruction error: 32.27
# Epoch 1:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 26.09
# Epoch 2:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 22.66
# Epoch 3:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 20.64
# Epoch 4:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 19.24
# Epoch 5:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 18.35
# Epoch 6:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 17.39
# Epoch 7:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 16.88
# Epoch 8:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 16.38
# Epoch 9:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 15.90
# Epoch 10:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 15.48
# Epoch 11:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 15.07
# Epoch 12:	#####################################################(256, 785)
# 784
# 	elapsed: 0.48s, reconstruction error: 14.89
# Epoch 13:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 14.42
# Epoch 14:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 14.22
# Epoch 15:	#####################################################(256, 785)
# 784
# 	elapsed: 0.69s, reconstruction error: 14.01
# Epoch 16:	#####################################################(256, 785)
# 784
# 	elapsed: 0.43s, reconstruction error: 14.05
# Epoch 17:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 13.64
# Epoch 18:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 13.48
# Epoch 19:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 13.29
# Epoch 20:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 13.12
# Epoch 21:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 12.98
# Epoch 22:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 12.73
# Epoch 23:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 12.64
# Epoch 24:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 12.43
# Epoch 25:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 12.65
# Epoch 26:	#####################################################(256, 785)
# 784
# 	elapsed: 0.41s, reconstruction error: 12.33
# Epoch 27:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 12.17
# Epoch 28:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 12.09
# Epoch 29:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 12.13
# Epoch 30:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 11.97
# Epoch 31:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 11.87
# Epoch 32:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 11.90
# Epoch 33:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 11.70
# Epoch 34:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 11.74
# Epoch 35:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 11.64
# Epoch 36:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 11.60
# Epoch 37:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 11.47
# Epoch 38:	#####################################################(256, 785)
# 784
# 	elapsed: 0.45s, reconstruction error: 11.66
# Epoch 39:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 11.32
# Epoch 40:	#####################################################(256, 785)
# 784
# 	elapsed: 0.40s, reconstruction error: 11.27
# Epoch 41:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 11.39
# Epoch 42:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 11.26
# Epoch 43:	#####################################################(256, 785)
# 784
# 	elapsed: 0.41s, reconstruction error: 11.15
# Epoch 44:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 11.24
# Epoch 45:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 11.16
# Epoch 46:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 11.19
# Epoch 47:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 11.01
# Epoch 48:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 11.00
# Epoch 49:	#####################################################(256, 785)
# 784
# 	elapsed: 0.31s, reconstruction error: 11.09
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# /tmp/ipykernel_4463/1605016057.py:2: DeprecationWarning: `newshape` keyword argument is deprecated, use `shape=...` or pass shape positionally instead. (deprecated in NumPy 2.1)
#   filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
# Epoch 0:	#####################################################(256, 785)
# 784
# 	elapsed: 0.62s, reconstruction error: 47.60
# Epoch 1:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 35.30
# Epoch 2:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 28.55
# Epoch 3:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 26.15
# Epoch 4:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 22.35
# Epoch 5:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 19.34
# Epoch 6:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 17.11
# Epoch 7:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 15.63
# Epoch 8:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 14.27
# Epoch 9:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 13.16
# Epoch 10:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 12.23
# Epoch 11:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 11.62
# Epoch 12:	#####################################################(256, 785)
# 784
# 	elapsed: 0.48s, reconstruction error: 10.94
# Epoch 13:	#####################################################(256, 785)
# 784
# 	elapsed: 0.47s, reconstruction error: 10.17
# Epoch 14:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 9.39
# Epoch 15:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 8.87
# Epoch 16:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 8.46
# Epoch 17:	#####################################################(256, 785)
# 784
# 	elapsed: 0.49s, reconstruction error: 8.02
# Epoch 18:	#####################################################(256, 785)
# 784
# 	elapsed: 0.55s, reconstruction error: 7.58
# Epoch 19:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 7.27
# Epoch 20:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 6.98
# Epoch 21:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 6.70
# Epoch 22:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 6.40
# Epoch 23:	#####################################################(256, 785)
# 784
# 	elapsed: 0.30s, reconstruction error: 5.91
# Epoch 24:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 5.75
# Epoch 25:	#####################################################(256, 785)
# 784
# 	elapsed: 0.38s, reconstruction error: 5.50
# Epoch 26:	#####################################################(256, 785)
# 784
# 	elapsed: 0.43s, reconstruction error: 5.24
# Epoch 27:	#####################################################(256, 785)
# 784
# 	elapsed: 0.64s, reconstruction error: 5.08
# Epoch 28:	#####################################################(256, 785)
# 784
# 	elapsed: 1.33s, reconstruction error: 5.08
# Epoch 29:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 4.79
# Epoch 30:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 4.88
# Epoch 31:	#####################################################(256, 785)
# 784
# 	elapsed: 0.72s, reconstruction error: 4.54
# Epoch 32:	#####################################################(256, 785)
# 784
# 	elapsed: 0.44s, reconstruction error: 4.47
# Epoch 33:	#####################################################(256, 785)
# 784
# 	elapsed: 0.39s, reconstruction error: 4.39
# Epoch 34:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 4.27
# Epoch 35:	#####################################################(256, 785)
# 784
# 	elapsed: 0.32s, reconstruction error: 4.22
# Epoch 36:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 4.15
# Epoch 37:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 4.13
# Epoch 38:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 4.09
# Epoch 39:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 4.07
# Epoch 40:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 4.01
# Epoch 41:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 3.96
# Epoch 42:	#####################################################(256, 785)
# 784
# 	elapsed: 0.44s, reconstruction error: 4.12
# Epoch 43:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 3.94
# Epoch 44:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 3.93
# Epoch 45:	#####################################################(256, 785)
# 784
# 	elapsed: 0.37s, reconstruction error: 3.91
# Epoch 46:	#####################################################(256, 785)
# 784
# 	elapsed: 0.33s, reconstruction error: 3.84
# Epoch 47:	#####################################################(256, 785)
# 784
# 	elapsed: 0.36s, reconstruction error: 4.05
# Epoch 48:	#####################################################(256, 785)
# 784
# 	elapsed: 0.35s, reconstruction error: 3.94
# Epoch 49:	#####################################################(256, 785)
# 784
# 	elapsed: 0.34s, reconstruction error: 4.02
# Training finished!
